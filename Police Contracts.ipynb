# %%
import collections
import json
import pathlib
import re
from typing import Dict

import requests
from bs4 import BeautifulSoup

from src import utils
from src import generate_directory

# %% [markdown]
# ## Fetching the contracts
#
# Here we're grabbing the database page we want to parse, parsing it, and pulling out the relevant links and jurisdiction names.

# %%
soup = utils.fetch_check_the_police_soup()
jurisdiction_data = utils.get_jurisdiction_and_link_soup(soup)
jurisdictions_to_pdf_map = utils.get_jurisdictions_and_pdf_links(jurisdiction_data)

# %% [markdown]
# ## Reorganize By State
#
# Here we're going to create the basic structure we want to use to keep track of our data, which should be by state and then jurisdiction, rather than jurisdiction as they have it on checkthepolice.org.

# %%
soup = utils.fetch_check_the_police_soup()
jd_to_soup_map = utils.get_jurisdiction_and_link_soup(soup)
jd_to_doc_map = utils.get_jurisdictions_and_pdf_links(jd_to_soup_map)
jd_to_doc_map.update(utils.hard_coded_jurisdictions_and_links)

state_jd_pdf_map = utils.transform_from_jd_to_state(jd_to_doc_map)

existing_files_map = utils.load_contract_paths()
directory = generate_directory.merge_dicts(state_jd_pdf_map, existing_files_map)

# %% [markdown]
# ## Generate the file directory for the frontend

# %%
from src.generate_directory import merge_dicts
directory = merge_dicts(state_jd_pdf_map, existing_files_map)
#print(json.dumps(merged, indent=4))

# %%
import pandas as pd
df = pd.read_csv('new_tags.csv', encoding='latin')
df['associated filename'].fillna('', inplace=True)
tags = df.to_dict(orient='records')
print(tags[0])
# Out:
# {'city/state': 'Albuquerque', 'associated filename': 'Police Union Contract.txt', 'expiration': '7/16/15', 'section': '18.1.5', 'language': "Human Resources Department files are a permanent record of an employee's performance with the City of Albuquerque. Such files will not be purged. However, employees who have been cleared of any charges shall not have reference of these charges included in their permanent personnel file.", 'category': 'Erases misconduct records', 'impact': 'Erases records if charges are dropped', 'id': 1, 'State': nan, 'Negotiating_Contract': 'Yes'}

# %%
for tag in tags:
    document_name = tag['associated filename'][:-4]

    if 'Bill' in tag['city/state']:
        jurisdiction = 'State'
        state = ''.join(tag['city/state'].split(' ')[:-4])
    else:
        jurisdiction = tag['city/state']
        state = utils.CITY_TO_STATE_MAP[tag['city/state']]
    
    entry = directory[state][jurisdiction][document_name]
    
    if 'tags' not in entry:
        entry['tags'] = set()
    entry['tags'].add(tag['category'])
    
for state in directory:
    for jd, files in directory[state].items():
        for file in files:
            if 'tags' in files[file]:
                files[file]['tags'] = list(files[file]['tags'])
# Out:
# {
#     "Illinois": {
#         "State": {
#             "Illinois Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Illinois/State/Illinois%20Police%20Bill%20of%20Rights.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Illinois-PBR.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations"
#                 ]
#             }
#         },
#         "Chicago": {
#             "Police Union Contract Accountability Fact Sheet": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Illinois/Chicago/Police%20Union%20Contract%20Accountability%20Fact%20Sheet.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/2o3dtucoap7fw7h/Chicago%20Police%20Contract%20Police%20Accountability%20Review%207.10.15.pdf?dl=0",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             },
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Illinois/Chicago/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Chicagopolicecontract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Arizona": {
#         "Phoenix": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Arizona/Phoenix/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Phoenix-police-union-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Chandler": {
#             "sergeant's": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Arizona/Chandler/sergeant%27s.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Chandler-police-sergeants-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations"
#                 ]
#             },
#             "police officers": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Arizona/Chandler/police%20officers.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Chandler-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Tucson": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Arizona/Tucson/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Tucson-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Mesa": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Arizona/Mesa/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Mesa-Police-Union-Contract.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "State": {
#             "": {
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         }
#     },
#     "Indiana": {
#         "Fort Wayne": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Indiana/Fort%20Wayne/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Fort-Wayne-Police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Indianapolis": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Indiana/Indianapolis/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Indianapolispolicecontract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Tennessee": {
#         "Metropolitan Nashville": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Tennessee/Metropolitan%20Nashville/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Nashville-police-contract.pdf"
#             }
#         },
#         "Memphis": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Tennessee/Memphis/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Memphis-Police-Contract.pdf"
#             },
#             "Police Union Contracts": {
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         }
#     },
#     "Maryland": {
#         "Baltimore": {
#             "non supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Maryland/Baltimore/non%20supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Baltimore-police-contract-14-16.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             },
#             "supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Maryland/Baltimore/supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Baltimore-police-sergeants-contract-11.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "State": {
#             "": {
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Oregon": {
#         "Portland": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Oregon/Portland/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Portland-police-union-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             },
#             "": {
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Oregon State": {
#             "": {
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         }
#     },
#     "Pennsylvania": {
#         "Pittsburgh": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Pennsylvania/Pittsburgh/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Pittsburg-contract.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Philadelphia": {
#             "original contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Pennsylvania/Philadelphia/original%20contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/2010_Master_FOP_Contract_-_Police_booklet.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             },
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Pennsylvania/Philadelphia/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Philadelphia-police-union-contract.pdf"
#             }
#         }
#     },
#     "Nebraska": {
#         "Omaha": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Nebraska/Omaha/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Omaha-police-contract.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Lincoln": {
#             "": {
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Ohio": {
#         "Toledo": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Ohio/Toledo/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Toledo-Police-Contract.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Columbus": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Ohio/Columbus/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/FOP-OLC-Contract-2017-2020-1.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Cincinnati": {
#             "supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Ohio/Cincinnati/supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Cincinnatipolicesupervisorscontract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             },
#             "non-supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Ohio/Cincinnati/non-supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Cincinnatipolicenonsupervisorscontract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Cleveland": {
#             "supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Ohio/Cleveland/supervisors.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/50br29dv446cgmk/Cleveland%20police%20supervisors%20contract.pdf?dl=0",
#                 "tags": [
#                     "Disqualifies Complaints"
#                 ]
#             },
#             "non-supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Ohio/Cleveland/non-supervisors.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/b26fdto7ddyzx8r/Cleveland%20police%20non%20supervisors%20contract.pdf?dl=0",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Colorado": {
#         "Aurora": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Colorado/Aurora/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Aurora-police-contract.pdf"
#             }
#         },
#         "Denver": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Colorado/Denver/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Denver-police-contract.PDF"
#             }
#         }
#     },
#     "New Jersey": {
#         "Jersey City": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20Jersey/Jersey%20City/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Jersey-City-Police-Contract.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         },
#         "Newark": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20Jersey/Newark/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Newark-police-supervisors-contract.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         }
#     },
#     "Alaska": {
#         "Anchorage": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Alaska/Anchorage/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Anchorage-police-contract.PDF",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Oklahoma": {
#         "Tulsa": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Oklahoma/Tulsa/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Tulsa-Police-Contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Oklahoma City": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Oklahoma/Oklahoma%20City/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Oklahoma-City-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         }
#     },
#     "Washington": {
#         "Spokane": {
#             "pt. 2": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Washington/Spokane/pt.%202.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Spokanepolicecontract2.PDF"
#             },
#             "p": {
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Seattle": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Washington/Seattle/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.seattle.gov/personnel/resources/pubs/SPOG_CBA_2015-2020.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Washington, DC": {
#         "Washington DC Metropolitan": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Washington%2C%20DC/Washington%20DC%20Metropolitan/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/MPD-FOP-CBA-FY-2013-2017_r.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Hawaii": {
#         "Honolulu": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Hawaii/Honolulu/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Honolulu-Police-Contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         }
#     },
#     "Minnesota": {
#         "St. Paul": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Minnesota/St.%20Paul/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/StPaulcontract.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "State": {
#             "Minnesota Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Minnesota/State/Minnesota%20Police%20Bill%20of%20Rights.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Minnesota-PBR.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Minneapolis": {
#             "": {
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             }
#         }
#     },
#     "Kansas": {
#         "Wichita": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Kansas/Wichita/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Wichita-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             }
#         }
#     },
#     "Texas": {
#         "Houston": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Texas/Houston/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Houstonpolicecontract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Laredo": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Texas/Laredo/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Laredo-Police-Contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Austin": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Texas/Austin/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/AustinPoliceContract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Corpus Christi": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Texas/Corpus%20Christi/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Corpus-Christie-Police-Contract-uiao.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         },
#         "San Antonio": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Texas/San%20Antonio/Police%20Union%20Contract.txt",
#                 "pdfUrl": "http://www.sanantonio.gov/portals/0/files/atty/CollectiveBargaining/PoliceCBA2016-2021.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Fort Worth": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Texas/Fort%20Worth/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Fort-Worth-police-contract.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Dallas": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Texas/Dallas/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Dallas-police-contract.pdf"
#             }
#         },
#         "El Paso": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Texas/El%20Paso/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/El-Paso-police-contract.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Limits Oversight / Discipline",
#                     "Disqualifies Complaints"
#                 ]
#             }
#         }
#     },
#     "Wisconsin": {
#         "State": {
#             "Wisconsin Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Wisconsin/State/Wisconsin%20Police%20Bill%20of%20Rights.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Wisconsin-PBR.pdf"
#             }
#         },
#         "Milwaukee": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Wisconsin/Milwaukee/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/milwaukee-police-contract.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         },
#         "Madison": {
#             "supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Wisconsin/Madison/supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Madisonpolicesupervisorscontract.pdf",
#                 "tags": [
#                     "Requires City Pay for Misconduct"
#                 ]
#             },
#             "non-supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Wisconsin/Madison/non-supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Madisonpolicenonsupervisorscontract.pdf",
#                 "tags": [
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         }
#     },
#     "California": {
#         "San Mateo": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/San%20Mateo/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Eureka": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Eureka/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Santa Ana": {
#             "non supervisor": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Santa%20Ana/non%20supervisor.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Santa-Ana-police-contract.pdf",
#                 "tags": [
#                     "Requires City Pay for Misconduct"
#                 ]
#             },
#             "extension": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Santa%20Ana/extension.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Santa-Ana-mou-extension.pdf"
#             },
#             "supervisor": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Santa%20Ana/supervisor.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Santa-Ana-police-supervisor-contract.pdf"
#             }
#         },
#         "Redwood City": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Redwood%20City/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Chula Vista": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Chula%20Vista/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/chula-vista-police-contract.pdf"
#             }
#         },
#         "Glendale": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Glendale/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Glendale-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "San Leandro": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/San%20Leandro/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Costa Mesa": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Costa%20Mesa/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Burbank": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Burbank/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Carlsbad": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Carlsbad/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Hayward": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Hayward/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Fresno": {
#             "non supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Fresno/non%20supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Fresno-police-contract.pdf"
#             },
#             "supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Fresno/supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Fresno-Police-supervisors-contract-jlfd.pdf"
#             }
#         },
#         "Bakersfield": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Bakersfield/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Bakersfield-police-contract.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Cypress": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Cypress/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Richmond": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Richmond/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Stockton": {
#             "MOU #2": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Stockton/MOU%20%232.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Stockton-police-contract-3.pdf"
#             },
#             "MOU #1": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Stockton/MOU%20%231.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Stockton-police-contract-2.pdf"
#             },
#             "contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Stockton/contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Stockton-police-contract.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "State": {
#             "California Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/State/California%20Police%20Bill%20of%20Rights.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/CApoliceofficersbillofrights.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Los Angeles": {
#             "LA City Charter Police Disciplinary Provisions": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Los%20Angeles/LA%20City%20Charter%20Police%20Disciplinary%20Provisions.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Los-Angeles-City-Charter-police-disciplinary-provisions.pdf"
#             },
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Los%20Angeles/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/LosAngelespolicecontract-o615.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         },
#         "Long Beach": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Long%20Beach/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Long-Beach-police-contract.pdf"
#             }
#         },
#         "Berkeley": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Berkeley/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Rialto": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Rialto/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Beverly Hills": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Beverly%20Hills/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "San Diego": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/San%20Diego/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/San-Diego-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Santa Cruz": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Santa%20Cruz/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "San Jose": {
#             "contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/San%20Jose/contract.txt",
#                 "pdfUrl": "https://www.sanjoseca.gov/home/showdocument?id=32017",
#                 "tags": [
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             },
#             "transfer policy": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/San%20Jose/transfer%20policy.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/SanJosepolicetransferpolicy.pdf"
#             }
#         },
#         "Riverside": {
#             "non supervisor": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Riverside/non%20supervisor.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Riverside-police-supervisor-contract-q4jz.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             },
#             "supervisor": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Riverside/supervisor.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Riverside-police-supervisor-contract.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Chico": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Chico/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Sacramento": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Sacramento/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Sacramento-police-contract.pdf",
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Los Angeles County": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Los%20Angeles%20County/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Daly City": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Daly%20City/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Oakland": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Oakland/Police%20Union%20Contract.txt",
#                 "pdfUrl": "http://www2.oaklandnet.com/oakca1/groups/hrm/documents/memorandum/oak057844.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Anaheim": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Anaheim/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Anaheim-police-contract.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         },
#         "East Palo Alto": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/East%20Palo%20Alto/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "Fremont": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Fremont/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Fremontpolicecontract.pdf"
#             }
#         },
#         "Irvine": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Irvine/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Irvine-CA-Police-Contract.pdf",
#                 "tags": [
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Santa Barbara": {
#             "pdfUrl": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/Santa%20Barbara/pdfUrl.txt",
#                 "pdfUrl": {}
#             }
#         },
#         "San Francisco": {
#             "MOU": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/San%20Francisco/MOU.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/edbznrqj37dbpbn/San%20Francisco%20police%20contract.pdf?dl=0"
#             },
#             "police": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/San%20Francisco/police.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/vbciik6nkzq7x1u/San%20Francisco%20police%20contract%202b.pdf?dl=0",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline"
#                 ]
#             },
#             "chiefs": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/California/San%20Francisco/chiefs.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/41azsngl2fl9f2e/San%20Francisco%20police%20chief%20contract.pdf?dl=0"
#             }
#         }
#     },
#     "Kentucky": {
#         "Lexington": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Kentucky/Lexington/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Lexington-Police-Contract.pdf",
#                 "tags": [
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Louisville": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Kentucky/Louisville/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Louisvillepolicecontract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "State": {
#             "": {
#                 "tags": [
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Louisiana": {
#         "State": {
#             "Louisiana Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Louisiana/State/Louisiana%20Police%20Bill%20of%20Rights.txt",
# ...
#                 "pdfUrl": "https://www.checkthepolice.org/s/Boston-police-supervisors-contract-hlc6.pdf",
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             },
#             "non supervisors": {
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "New Mexico": {
#         "State": {
#             "New Mexico Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20Mexico/State/New%20Mexico%20Police%20Bill%20of%20Rights.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/New-Mexico-PBR.pdf"
#             }
#         },
#         "Albuquerque": {
#             "New Mexico Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20Mexico/Albuquerque/New%20Mexico%20Police%20Bill%20of%20Rights.txt",
#                 "pdfUrl": {}
#             },
#             "Police Union Contract Police Accountability Fact Sheet": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20Mexico/Albuquerque/Police%20Union%20Contract%20Police%20Accountability%20Fact%20Sheet.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/o80983zlasmwlu5/Albuquerque%20Police%20Contract%20Police%20Accountability%20Review%207.10.15.pdf?dl=0"
#             },
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20Mexico/Albuquerque/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Albuquerque-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Florida": {
#         "Orlando": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Florida/Orlando/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/4ap3loq4his2bfl/Orlandopolicecontract.pdf?dl=0",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Tampa": {
#             "non supervisor": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Florida/Tampa/non%20supervisor.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Tampa-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Limits Oversight / Discipline"
#                 ]
#             },
#             "supervisor": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Florida/Tampa/supervisor.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Tampa-police-lieutenant-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "State": {
#             "Florida Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Florida/State/Florida%20Police%20Bill%20of%20Rights.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Florida-PBR.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Jacksonville": {
#             "supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Florida/Jacksonville/supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Jacksonville-supervisor-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             },
#             "non-supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Florida/Jacksonville/non-supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Jacksonville-non-supervisor-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "St. Petersburg": {
#             "non-supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Florida/St.%20Petersburg/non-supervisors.txt",
#                 "pdfUrl": "https://www.stpete.org/city_departments/human_resources/docs/PBA Contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Hialeah": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Florida/Hialeah/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Hialeah-Police-Contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Miami": {
#             "": {
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         }
#     },
#     "New York": {
#         "Rochester": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/Rochester/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Rochester-police-contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Erases misconduct records",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Buffalo": {
#             "pt. 2": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/Buffalo/pt.%202.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/BuffaloPD_Interest_Arbitration_Award_July_1_2007-June_30_2009.pdf"
#             },
#             "pt. 1": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/Buffalo/pt.%201.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/BuffaloPD_Contract_Agreements.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         },
#         "New York": {
#             "police officers [updated]": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/New%20York/police%20officers%20%5Bupdated%5D.txt",
#                 "pdfUrl": "https://www1.nyc.gov/assets/olr/downloads/pdf/collectivebargaining/pba-nyc-moa-2012-2017.pdf"
#             },
#             "sergeants": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/New%20York/sergeants.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/NYC-police-sergeants-contract.pdf"
#             },
#             "captains": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/New%20York/captains.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/NYC-police-captains-contract.pdf",
#                 "tags": [
#                     "Erases misconduct records"
#                 ]
#             },
#             "captains revision": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/New%20York/captains%20revision.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/NYC-captains-reopener.pdf"
#             },
#             "mou": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/New%20York/mou.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/NYC-police-mou.pdf"
#             },
#             "detectives": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/New%20York/detectives.txt",
#                 "pdfUrl": "http://www.lris.com/wp-content/uploads/contracts/newyork_ny_police_detectives.pdf"
#             },
#             "non supervisors": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/New%20York/New%20York/non%20supervisors.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/NYC-police-contract.pdf",
#                 "tags": [
#                     "Erases misconduct records"
#                 ]
#             }
#         }
#     },
#     "Nevada": {
#         "State": {
#             "Nevada Police Bill of Rights": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Nevada/State/Nevada%20Police%20Bill%20of%20Rights.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/Nevada-PBR.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct"
#                 ]
#             }
#         },
#         "Las Vegas Metropolitan": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Nevada/Las%20Vegas%20Metropolitan/Police%20Union%20Contract.txt",
#                 "pdfUrl": "http://lvppa.com/wp-content/uploads/2016/10/CBA-2016-2019-signed.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "North Las Vegas": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Nevada/North%20Las%20Vegas/Police%20Union%20Contract.txt",
#                 "pdfUrl": "https://www.checkthepolice.org/s/North-Las-Vegas-Police-Contract.pdf",
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         },
#         "Reno": {
#             "Police Union Contract": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Nevada/Reno/Police%20Union%20Contract.txt",
#                 "pdfUrl": "http://www.reno.gov/home/showdocument?id=52642",
#                 "tags": [
#                     "Limits Oversight / Discipline",
#                     "Requires City Pay for Misconduct",
#                     "Erases misconduct records"
#                 ]
#             }
#         },
#         "Henderson": {
#             "pt. 2": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Nevada/Henderson/pt.%202.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/z8t1o1682en9vlf/Henderson%20police%20contract%202.pdf?dl=0",
#                 "tags": [
#                     "Limits Oversight / Discipline",
#                     "Erases misconduct records"
#                 ]
#             },
#             "pt. 1": {
#                 "textUrl": "https://raw.githubusercontent.com/PoliceContracts/PoliceContracts/master/Nevada/Henderson/pt.%201.txt",
#                 "pdfUrl": "https://www.dropbox.com/s/tqrnq7qfe4a5cdt/Henderson%20police%20contract.pdf?dl=0",
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Delaware": {
#         "State": {
#             "": {
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "NewMexico": {
#         "State": {
#             "New Mexico Police Bill of Rights": {
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Erases misconduct records"
#                 ]
#             }
#         }
#     },
#     "RhodeIsland": {
#         "State": {
#             "": {
#                 "tags": [
#                     "Gives officers unfair access to information",
#                     "Restricts/Delays Interrogations",
#                     "Disqualifies Complaints",
#                     "Requires City Pay for Misconduct",
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "Virginia": {
#         "State": {
#             "": {
#                 "tags": [
#                     "Limits Oversight / Discipline"
#                 ]
#             }
#         }
#     },
#     "WestVirginia": {
#         "State": {
#             "": {
#                 "tags": [
#                     "Restricts/Delays Interrogations"
#                 ]
#             }
#         }
#     }
# }

# %% [markdown]
# ## Fixing the

# %%
import requests
from bs4 import BeautifulSoup
from bs4.element import Tag

import re

BASE_URL = "https://www.checkthepolice.org"

CITY_REGEX_PATTERN = re.compile(
    r'(.*) (Metropolitan Police Department|Police Bureau|Sheriff\'s Office|Division of Police|Bureau of Police|Police Department).*'
)


def get_jurisdiction_and_link_soup() -> Dict[str, Tag]:
    """
    Hits checkthepolice.org and returns a list of
    BeautifulSoup objects containing
    :return:
    """
    db_page = f"{BASE_URL}/database"

    base_page_html = requests.get(db_page).text
    base_page_soup = BeautifulSoup(base_page_html, 'lxml')
    contract_soups = list(base_page_soup.find_all('div', {'class': 'sqs-block-content'}))[0]
    jurisdiction_to_soup_map = {}
    for jd in contract_soups:
        if jd.strong and '✔️' in jd.strong.text:
            try:
                jurisdiction_name = CITY_REGEX_PATTERN.findall(jd.strong.text)[0]
                jurisdiction_to_soup_map[jurisdiction_name[0]] = jd
            except IndexError:
                print('failed', jd.strong.text)
    return jurisdiction_to_soup_map

# %%
hard_coded_jurisdictions_and_links = {
    'Honolulu': {
        'Police Union Contract': 'https://www.checkthepolice.org/s/Honolulu-Police-Contract.pdf',
    },
    'Kansas City, MO': {
        'Police Union Contract': 'https://www.checkthepolice.org/s/Kansas-City-MO-Police-Contract.pdf'
    },
    'Lexington': {
        'Police Union Contract': 'https://www.checkthepolice.org/s/Lexington-Police-Contract.pdf'
    },
    'Mesa': {
        'Police Union Contract': 'https://www.checkthepolice.org/s/Mesa-Police-Union-Contract.pdf'
    },
    'Toledo': {
        'Police Union Contract': 'https://www.checkthepolice.org/s/Toledo-Police-Contract.pdf'
    },
}

# %% [markdown]
# ## Split files that are too big

# %%
# Out:
# 358400

# %%
    import glob
    contract_paths = [pathlib.Path(p) for p in glob.glob('./contracts/*/*/*')]

    # Github only indexes files up to 384kb, so setting the max to a conservative 350
    MAX_SIZE = 1024 * 350

    print('MAX_SIZE', MAX_SIZE)
    import os
    for path in contract_paths:
        with path.open() as f:
            full_text = f.read()
        # Using the number of characters as opposed to some other measure of size
        # because it should make it easier to be consistent
        if len(full_text) > MAX_SIZE:
            num_groups = 1 + len(full_text) // MAX_SIZE
            for i in range(num_groups):
                new_filename = str(path).replace('.txt', f' {i+1}.txt')

                # chunking
                starting_index = i * MAX_SIZE
                ending_index = (i + 1) * MAX_SIZE
                text_chunk = full_text[starting_index:ending_index]

                with open(new_filename, 'w') as f:
                    f.write(text_chunk)

            # Remove the old file
            path.unlink()
# Out:
# MAX_SIZE 358400

# %% [markdown]
# ## Zip up files by tag

# %%
with open('directory.json', 'r') as f:
    directory = json.load(f)

tags = collections.defaultdict(list)

import dataclasses

from collections import defaultdict

class Directory:
    
    def __init__(self):
        self._dir = collections.defaultdict
        
    def write_json(filename):
        pass

@dataclasses.dataclass
class Document:
    state: str
    jurisdiction: str
    filename: str
    
    def path(self) -> pathlib.Path:
        path = pathlib.Path('./contracts/') / self.state / self.jurisdiction / f"{self.filename}.txt"
        return path
    
    def from_path(path: pathlib.Path):
        _, state, jurisdiction, filename = str(path).split('/')
        return Document(
            state,
            jurisdiction,
            filename
        )
    
    def get_text():
        with self.path().open() as f:
            return f.read()

for state, jurisdictions in directory.items():
    for jurisdiction, documents in jurisdictions.items():
        for doc_name, properties in documents.items():
            if 'tags' in properties:
                for tag in properties['tags']:
                    doc = Document(state, jurisdiction, doc_name)
                    tags[tag].append(doc)

# %%
contract_paths = [pathlib.Path(p) for p in glob.glob('./contracts/*/*/*')]
import zipfile

for tag in tags:
    zip_file_name = tag.replace('/',' or ')
    zip_file_name = f"./tag_archive/{zip_file_name}.zip"
    print(zip_file_name)
    with zipfile.ZipFile(zip_file_name, 'w') as zipf:
        for document in tags[tag]:
            print(document)
            zipf.write(document.path())
# Out:
# ./tag_archive/Gives officers unfair access to information.zip
# Document(state='Illinois', jurisdiction='State', filename='Illinois Police Bill of Rights')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract Accountability Fact Sheet')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 1')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 2')
# Document(state='Arizona', jurisdiction='Phoenix', filename='Police Union Contract')
# Document(state='Arizona', jurisdiction='Chandler', filename="sergeant's")
# Document(state='Arizona', jurisdiction='Chandler', filename='police officers')
# Document(state='Arizona', jurisdiction='Tucson', filename='Police Union Contract')
# Document(state='Indiana', jurisdiction='Fort Wayne', filename='Police Union Contract')
# Document(state='Indiana', jurisdiction='Indianapolis', filename='Police Union Contract')
# Document(state='Tennessee', jurisdiction='Memphis', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Columbus', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Cincinnati', filename='supervisors')
# Document(state='Ohio', jurisdiction='Cincinnati', filename='non-supervisors')
# Document(state='Ohio', jurisdiction='Cleveland', filename='non-supervisors')
# Document(state='Alaska', jurisdiction='Anchorage', filename='Police Union Contract')
# Document(state='Oklahoma', jurisdiction='Tulsa', filename='Police Union Contract')
# Document(state='Oklahoma', jurisdiction='Oklahoma City', filename='Police Union Contract')
# Document(state='Washington', jurisdiction='Seattle', filename='Police Union Contract')
# Document(state='Washington, DC', jurisdiction='Washington DC Metropolitan', filename='Police Union Contract')
# Document(state='Hawaii', jurisdiction='Honolulu', filename='Police Union Contract')
# Document(state='Minnesota', jurisdiction='State', filename='Minnesota Police Bill of Rights')
# Document(state='Kansas', jurisdiction='Wichita', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Houston', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Laredo', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Austin', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Corpus Christi', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 1')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 2')
# Document(state='California', jurisdiction='Glendale', filename='Police Union Contract')
# Document(state='California', jurisdiction='State', filename='California Police Bill of Rights')
# Document(state='California', jurisdiction='San Diego', filename='Police Union Contract')
# Document(state='California', jurisdiction='San Francisco', filename='police')
# Document(state='Kentucky', jurisdiction='Louisville', filename='Police Union Contract')
# Document(state='Louisiana', jurisdiction='State', filename='Louisiana Police Bill of Rights')
# Document(state='Louisiana', jurisdiction='Baton Rouge', filename='Police Union Contract')
# Document(state='Missouri', jurisdiction='Kansas City, MO', filename='Police Union Contract')
# Document(state='Michigan', jurisdiction='Detroit', filename='police officers')
# Document(state='New Mexico', jurisdiction='Albuquerque', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Orlando', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Tampa', filename='non supervisor')
# Document(state='Florida', jurisdiction='Tampa', filename='supervisor')
# Document(state='Florida', jurisdiction='State', filename='Florida Police Bill of Rights')
# Document(state='Florida', jurisdiction='Jacksonville', filename='supervisors')
# Document(state='Florida', jurisdiction='Jacksonville', filename='non-supervisors')
# Document(state='Florida', jurisdiction='St. Petersburg', filename='non-supervisors')
# Document(state='Florida', jurisdiction='Hialeah', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Rochester', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Buffalo', filename='pt. 1')
# Document(state='Nevada', jurisdiction='State', filename='Nevada Police Bill of Rights')
# Document(state='Nevada', jurisdiction='Las Vegas Metropolitan', filename='Police Union Contract')
# Document(state='Nevada', jurisdiction='North Las Vegas', filename='Police Union Contract')
# ./tag_archive/Restricts or Delays Interrogations.zip
# Document(state='Illinois', jurisdiction='State', filename='Illinois Police Bill of Rights')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract Accountability Fact Sheet')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 1')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 2')
# Document(state='Arizona', jurisdiction='Phoenix', filename='Police Union Contract')
# Document(state='Arizona', jurisdiction='Chandler', filename="sergeant's")
# Document(state='Arizona', jurisdiction='Chandler', filename='police officers')
# Document(state='Arizona', jurisdiction='Tucson', filename='Police Union Contract')
# Document(state='Indiana', jurisdiction='Fort Wayne', filename='Police Union Contract')
# Document(state='Tennessee', jurisdiction='Memphis', filename='Police Union Contract')
# Document(state='Maryland', jurisdiction='Baltimore', filename='non supervisors')
# Document(state='Maryland', jurisdiction='Baltimore', filename='supervisors')
# Document(state='Nebraska', jurisdiction='Omaha', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Toledo', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Columbus', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Cleveland', filename='non-supervisors')
# Document(state='New Jersey', jurisdiction='Jersey City', filename='Police Union Contract')
# Document(state='Alaska', jurisdiction='Anchorage', filename='Police Union Contract')
# Document(state='Oklahoma', jurisdiction='Tulsa', filename='Police Union Contract')
# Document(state='Oklahoma', jurisdiction='Oklahoma City', filename='Police Union Contract')
# Document(state='Washington', jurisdiction='Spokane', filename='pt. 2')
# Document(state='Washington', jurisdiction='Seattle', filename='Police Union Contract')
# Document(state='Washington, DC', jurisdiction='Washington DC Metropolitan', filename='Police Union Contract')
# Document(state='Hawaii', jurisdiction='Honolulu', filename='Police Union Contract')
# Document(state='Minnesota', jurisdiction='St. Paul', filename='Police Union Contract')
# Document(state='Minnesota', jurisdiction='State', filename='Minnesota Police Bill of Rights')
# Document(state='Kansas', jurisdiction='Wichita', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Houston', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Laredo', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Austin', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Corpus Christi', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 1')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 2')
# Document(state='Texas', jurisdiction='Fort Worth', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='El Paso', filename='Police Union Contract')
# Document(state='Wisconsin', jurisdiction='Milwaukee', filename='Police Union Contract 1')
# Document(state='Wisconsin', jurisdiction='Milwaukee', filename='Police Union Contract 2')
# Document(state='California', jurisdiction='State', filename='California Police Bill of Rights')
# Document(state='California', jurisdiction='San Diego', filename='Police Union Contract')
# Document(state='California', jurisdiction='Sacramento', filename='Police Union Contract')
# Document(state='California', jurisdiction='San Francisco', filename='police')
# Document(state='Kentucky', jurisdiction='Louisville', filename='Police Union Contract')
# Document(state='Louisiana', jurisdiction='State', filename='Louisiana Police Bill of Rights')
# Document(state='Louisiana', jurisdiction='Baton Rouge', filename='Police Union Contract')
# Document(state='Missouri', jurisdiction='Kansas City, MO', filename='Police Union Contract')
# Document(state='Michigan', jurisdiction='Detroit', filename='police officers')
# Document(state='Michigan', jurisdiction='Detroit', filename='lieutenants')
# Document(state='Michigan', jurisdiction='Detroit', filename='command officers')
# Document(state='New Mexico', jurisdiction='Albuquerque', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Orlando', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Tampa', filename='non supervisor')
# Document(state='Florida', jurisdiction='Tampa', filename='supervisor')
# Document(state='Florida', jurisdiction='State', filename='Florida Police Bill of Rights')
# Document(state='Florida', jurisdiction='Jacksonville', filename='supervisors')
# Document(state='Florida', jurisdiction='Jacksonville', filename='non-supervisors')
# Document(state='Florida', jurisdiction='St. Petersburg', filename='non-supervisors')
# Document(state='Florida', jurisdiction='Hialeah', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Rochester', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Buffalo', filename='pt. 1')
# Document(state='Nevada', jurisdiction='State', filename='Nevada Police Bill of Rights')
# Document(state='Nevada', jurisdiction='Las Vegas Metropolitan', filename='Police Union Contract')
# Document(state='Nevada', jurisdiction='North Las Vegas', filename='Police Union Contract')
# ./tag_archive/Limits Oversight  or  Discipline.zip
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract Accountability Fact Sheet')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 1')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 2')
# Document(state='Arizona', jurisdiction='Phoenix', filename='Police Union Contract')
# Document(state='Arizona', jurisdiction='Chandler', filename='police officers')
# Document(state='Arizona', jurisdiction='Tucson', filename='Police Union Contract')
# Document(state='Arizona', jurisdiction='Mesa', filename='Police Union Contract')
# Document(state='Indiana', jurisdiction='Fort Wayne', filename='Police Union Contract')
# Document(state='Indiana', jurisdiction='Indianapolis', filename='Police Union Contract')
# Document(state='Tennessee', jurisdiction='Memphis', filename='Police Union Contract')
# Document(state='Maryland', jurisdiction='Baltimore', filename='non supervisors')
# Document(state='Maryland', jurisdiction='Baltimore', filename='supervisors')
# Document(state='Pennsylvania', jurisdiction='Pittsburgh', filename='Police Union Contract')
# Document(state='Pennsylvania', jurisdiction='Philadelphia', filename='original contract')
# Document(state='Nebraska', jurisdiction='Omaha', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Toledo', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Columbus', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Cincinnati', filename='supervisors')
# Document(state='Ohio', jurisdiction='Cincinnati', filename='non-supervisors')
# Document(state='Ohio', jurisdiction='Cleveland', filename='non-supervisors')
# Document(state='New Jersey', jurisdiction='Jersey City', filename='Police Union Contract')
# Document(state='New Jersey', jurisdiction='Newark', filename='Police Union Contract')
# Document(state='Alaska', jurisdiction='Anchorage', filename='Police Union Contract')
# Document(state='Oklahoma', jurisdiction='Tulsa', filename='Police Union Contract')
# Document(state='Oklahoma', jurisdiction='Oklahoma City', filename='Police Union Contract')
# Document(state='Washington', jurisdiction='Spokane', filename='pt. 2')
# Document(state='Washington', jurisdiction='Seattle', filename='Police Union Contract')
# Document(state='Washington, DC', jurisdiction='Washington DC Metropolitan', filename='Police Union Contract')
# Document(state='Hawaii', jurisdiction='Honolulu', filename='Police Union Contract')
# Document(state='Minnesota', jurisdiction='St. Paul', filename='Police Union Contract')
# Document(state='Minnesota', jurisdiction='State', filename='Minnesota Police Bill of Rights')
# Document(state='Texas', jurisdiction='Houston', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Laredo', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Austin', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Corpus Christi', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 1')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 2')
# Document(state='Texas', jurisdiction='Fort Worth', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='El Paso', filename='Police Union Contract')
# Document(state='Wisconsin', jurisdiction='Milwaukee', filename='Police Union Contract 1')
# Document(state='Wisconsin', jurisdiction='Milwaukee', filename='Police Union Contract 2')
# Document(state='California', jurisdiction='Glendale', filename='Police Union Contract')
# Document(state='California', jurisdiction='Bakersfield', filename='Police Union Contract')
# Document(state='California', jurisdiction='Stockton', filename='contract')
# Document(state='California', jurisdiction='State', filename='California Police Bill of Rights')
# Document(state='California', jurisdiction='Los Angeles', filename='Police Union Contract 1')
# Document(state='California', jurisdiction='Los Angeles', filename='Police Union Contract 2')
# Document(state='California', jurisdiction='San Diego', filename='Police Union Contract')
# Document(state='California', jurisdiction='San Jose', filename='contract')
# Document(state='California', jurisdiction='Riverside', filename='non supervisor')
# Document(state='California', jurisdiction='Riverside', filename='supervisor')
# Document(state='California', jurisdiction='Sacramento', filename='Police Union Contract')
# Document(state='California', jurisdiction='Oakland', filename='Police Union Contract')
# Document(state='California', jurisdiction='Anaheim', filename='Police Union Contract')
# Document(state='California', jurisdiction='San Francisco', filename='police')
# Document(state='Kentucky', jurisdiction='Lexington', filename='Police Union Contract')
# Document(state='Kentucky', jurisdiction='Louisville', filename='Police Union Contract')
# Document(state='Louisiana', jurisdiction='State', filename='Louisiana Police Bill of Rights')
# Document(state='Missouri', jurisdiction='St. Louis Metropolitan', filename='Police Union Contract')
# Document(state='Missouri', jurisdiction='Kansas City, MO', filename='Police Union Contract')
# Document(state='Michigan', jurisdiction='Detroit', filename='police officers')
# Document(state='Michigan', jurisdiction='Detroit', filename='lieutenants')
# Document(state='Massachusetts', jurisdiction='Boston', filename='non supervisor')
# Document(state='Massachusetts', jurisdiction='Boston', filename='supervisors')
# Document(state='New Mexico', jurisdiction='Albuquerque', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Orlando', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Tampa', filename='non supervisor')
# Document(state='Florida', jurisdiction='Tampa', filename='supervisor')
# Document(state='Florida', jurisdiction='State', filename='Florida Police Bill of Rights')
# Document(state='Florida', jurisdiction='Jacksonville', filename='supervisors')
# Document(state='Florida', jurisdiction='Jacksonville', filename='non-supervisors')
# Document(state='Florida', jurisdiction='St. Petersburg', filename='non-supervisors')
# Document(state='Florida', jurisdiction='Hialeah', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Rochester', filename='Police Union Contract')
# Document(state='Nevada', jurisdiction='State', filename='Nevada Police Bill of Rights')
# Document(state='Nevada', jurisdiction='Las Vegas Metropolitan', filename='Police Union Contract')
# Document(state='Nevada', jurisdiction='North Las Vegas', filename='Police Union Contract')
# Document(state='Nevada', jurisdiction='Reno', filename='Police Union Contract')
# Document(state='Nevada', jurisdiction='Henderson', filename='pt. 2')
# Document(state='Nevada', jurisdiction='Henderson', filename='pt. 1')
# ./tag_archive/Erases misconduct records.zip
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract Accountability Fact Sheet')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 1')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 2')
# Document(state='Arizona', jurisdiction='Phoenix', filename='Police Union Contract')
# Document(state='Arizona', jurisdiction='Chandler', filename='police officers')
# Document(state='Tennessee', jurisdiction='Memphis', filename='Police Union Contract')
# Document(state='Maryland', jurisdiction='Baltimore', filename='non supervisors')
# Document(state='Maryland', jurisdiction='Baltimore', filename='supervisors')
# Document(state='Pennsylvania', jurisdiction='Pittsburgh', filename='Police Union Contract')
# Document(state='Pennsylvania', jurisdiction='Philadelphia', filename='original contract')
# Document(state='Nebraska', jurisdiction='Omaha', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Toledo', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Cincinnati', filename='supervisors')
# Document(state='Ohio', jurisdiction='Cincinnati', filename='non-supervisors')
# Document(state='Ohio', jurisdiction='Cleveland', filename='non-supervisors')
# Document(state='Alaska', jurisdiction='Anchorage', filename='Police Union Contract')
# Document(state='Oklahoma', jurisdiction='Tulsa', filename='Police Union Contract')
# Document(state='Washington', jurisdiction='Spokane', filename='pt. 2')
# Document(state='Washington', jurisdiction='Seattle', filename='Police Union Contract')
# Document(state='Washington, DC', jurisdiction='Washington DC Metropolitan', filename='Police Union Contract')
# Document(state='Hawaii', jurisdiction='Honolulu', filename='Police Union Contract')
# Document(state='Minnesota', jurisdiction='St. Paul', filename='Police Union Contract')
# Document(state='Kansas', jurisdiction='Wichita', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Houston', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Laredo', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Austin', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 1')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 2')
# Document(state='California', jurisdiction='Sacramento', filename='Police Union Contract')
# Document(state='California', jurisdiction='Irvine', filename='Police Union Contract')
# Document(state='Kentucky', jurisdiction='Lexington', filename='Police Union Contract')
# Document(state='Kentucky', jurisdiction='Louisville', filename='Police Union Contract')
# Document(state='Louisiana', jurisdiction='State', filename='Louisiana Police Bill of Rights')
# Document(state='Louisiana', jurisdiction='Baton Rouge', filename='Police Union Contract')
# Document(state='Michigan', jurisdiction='Detroit', filename='police officers')
# Document(state='Michigan', jurisdiction='Detroit', filename='lieutenants')
# Document(state='New Mexico', jurisdiction='Albuquerque', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Orlando', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Jacksonville', filename='supervisors')
# Document(state='Florida', jurisdiction='Jacksonville', filename='non-supervisors')
# Document(state='Florida', jurisdiction='Hialeah', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Rochester', filename='Police Union Contract')
# Document(state='New York', jurisdiction='New York', filename='captains')
# Document(state='New York', jurisdiction='New York', filename='non supervisors')
# Document(state='Nevada', jurisdiction='Las Vegas Metropolitan', filename='Police Union Contract')
# Document(state='Nevada', jurisdiction='Reno', filename='Police Union Contract')
# Document(state='Nevada', jurisdiction='Henderson', filename='pt. 2')
# ./tag_archive/Requires City Pay for Misconduct.zip
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 1')
# Document(state='Illinois', jurisdiction='Chicago', filename='Police Union Contract 2')
# Document(state='Arizona', jurisdiction='Phoenix', filename='Police Union Contract')
# Document(state='Arizona', jurisdiction='Tucson', filename='Police Union Contract')
# Document(state='Maryland', jurisdiction='Baltimore', filename='non supervisors')
# Document(state='Maryland', jurisdiction='Baltimore', filename='supervisors')
# Document(state='Pennsylvania', jurisdiction='Pittsburgh', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Columbus', filename='Police Union Contract')
# Document(state='New Jersey', jurisdiction='Jersey City', filename='Police Union Contract')
# Document(state='New Jersey', jurisdiction='Newark', filename='Police Union Contract')
# Document(state='Alaska', jurisdiction='Anchorage', filename='Police Union Contract')
# Document(state='Oklahoma', jurisdiction='Oklahoma City', filename='Police Union Contract')
# Document(state='Washington', jurisdiction='Seattle', filename='Police Union Contract')
# Document(state='Washington, DC', jurisdiction='Washington DC Metropolitan', filename='Police Union Contract')
# Document(state='Minnesota', jurisdiction='St. Paul', filename='Police Union Contract')
# Document(state='Kansas', jurisdiction='Wichita', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Laredo', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Austin', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Corpus Christi', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 1')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 2')
# Document(state='Texas', jurisdiction='El Paso', filename='Police Union Contract')
# Document(state='Wisconsin', jurisdiction='Milwaukee', filename='Police Union Contract 1')
# Document(state='Wisconsin', jurisdiction='Milwaukee', filename='Police Union Contract 2')
# Document(state='Wisconsin', jurisdiction='Madison', filename='supervisors')
# Document(state='Wisconsin', jurisdiction='Madison', filename='non-supervisors')
# Document(state='California', jurisdiction='Santa Ana', filename='non supervisor')
# Document(state='California', jurisdiction='State', filename='California Police Bill of Rights')
# Document(state='California', jurisdiction='Los Angeles', filename='Police Union Contract 1')
# Document(state='California', jurisdiction='Los Angeles', filename='Police Union Contract 2')
# Document(state='California', jurisdiction='San Jose', filename='contract')
# Document(state='California', jurisdiction='Sacramento', filename='Police Union Contract')
# Document(state='California', jurisdiction='Anaheim', filename='Police Union Contract')
# Document(state='California', jurisdiction='Irvine', filename='Police Union Contract')
# Document(state='Kentucky', jurisdiction='Lexington', filename='Police Union Contract')
# Document(state='Kentucky', jurisdiction='Louisville', filename='Police Union Contract')
# Document(state='Louisiana', jurisdiction='Baton Rouge', filename='Police Union Contract')
# Document(state='Missouri', jurisdiction='St. Louis Metropolitan', filename='Police Union Contract')
# Document(state='Michigan', jurisdiction='Detroit', filename='police officers')
# Document(state='Michigan', jurisdiction='Detroit', filename='lieutenants')
# Document(state='Michigan', jurisdiction='Detroit', filename='command officers')
# Document(state='New Mexico', jurisdiction='Albuquerque', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Orlando', filename='Police Union Contract')
# Document(state='Florida', jurisdiction='Tampa', filename='non supervisor')
# Document(state='Florida', jurisdiction='Tampa', filename='supervisor')
# Document(state='Florida', jurisdiction='Jacksonville', filename='supervisors')
# Document(state='Florida', jurisdiction='Jacksonville', filename='non-supervisors')
# Document(state='Florida', jurisdiction='St. Petersburg', filename='non-supervisors')
# Document(state='Florida', jurisdiction='Hialeah', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Buffalo', filename='pt. 1')
# Document(state='Nevada', jurisdiction='State', filename='Nevada Police Bill of Rights')
# Document(state='Nevada', jurisdiction='Reno', filename='Police Union Contract')
# ./tag_archive/Disqualifies Complaints.zip
# Document(state='Arizona', jurisdiction='Tucson', filename='Police Union Contract')
# Document(state='Indiana', jurisdiction='Indianapolis', filename='Police Union Contract')
# Document(state='Nebraska', jurisdiction='Omaha', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Toledo', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Columbus', filename='Police Union Contract')
# Document(state='Ohio', jurisdiction='Cleveland', filename='supervisors')
# Document(state='Ohio', jurisdiction='Cleveland', filename='non-supervisors')
# Document(state='New Jersey', jurisdiction='Jersey City', filename='Police Union Contract')
# Document(state='Washington', jurisdiction='Spokane', filename='pt. 2')
# Document(state='Washington', jurisdiction='Seattle', filename='Police Union Contract')
# Document(state='Washington, DC', jurisdiction='Washington DC Metropolitan', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Houston', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='Austin', filename='Police Union Contract')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 1')
# Document(state='Texas', jurisdiction='San Antonio', filename='Police Union Contract 2')
# Document(state='Texas', jurisdiction='El Paso', filename='Police Union Contract')
# Document(state='California', jurisdiction='Glendale', filename='Police Union Contract')
# Document(state='California', jurisdiction='State', filename='California Police Bill of Rights')
# Document(state='California', jurisdiction='San Diego', filename='Police Union Contract')
# Document(state='California', jurisdiction='Sacramento', filename='Police Union Contract')
# Document(state='Kentucky', jurisdiction='Lexington', filename='Police Union Contract')
# Document(state='Kentucky', jurisdiction='Louisville', filename='Police Union Contract')
# Document(state='Louisiana', jurisdiction='State', filename='Louisiana Police Bill of Rights')
# Document(state='Florida', jurisdiction='Tampa', filename='non supervisor')
# Document(state='Florida', jurisdiction='Tampa', filename='supervisor')
# Document(state='Florida', jurisdiction='State', filename='Florida Police Bill of Rights')
# Document(state='Florida', jurisdiction='St. Petersburg', filename='non-supervisors')
# Document(state='Florida', jurisdiction='Hialeah', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Rochester', filename='Police Union Contract')
# Document(state='New York', jurisdiction='Buffalo', filename='pt. 1')

# %% [markdown]
# ## Renaming the contracts and updating the structure

# %%
import json
with open('directory.json', 'r') as f:
    directory = json.load(f)
    
import collections
doc = collections.namedtuple("DOCUMENT", ['state', 'jurisdiction', 'document', 'pdf_url', 'text_url', 'title'])
results = []
for state, jurisdictions in directory.items():
    for jurisdiction, documents in jurisdictions.items():
        for document, data in documents.items():
           results.append([
               state,
               jurisdiction,
               document,
               data.get('pdfUrl'),
               data.get('textUrl'),
               data.get('title')
           ]) 

import csv
with open('directory.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['state', 'jurisdiction', 'document', 'pdf_url', 'text_url', 'title'])
    writer.writerows(results)

# %%
from pathlib import Path
base_path = Path('./contracts')
for result in results:
    path = base_path / result[0] / result[1] / f"{result[2]}.txt"
    if path.exists():
        if result[1] == "State":
            new_filename = path.parent / f"{result[2]}.txt"
        else:
            new_filename = path.parent / f"{result[1]} {result[2]}.txt"
        
        path.rename(new_filename)

# %%
with open('directory.csv') as f:
