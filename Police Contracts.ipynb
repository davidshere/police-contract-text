# %%
from bs4 import BeautifulSoup
import requests

# %%
base_url = "https://www.checkthepolice.org"
db_page = f"{base_url}/database"

base_page_html = requests.get(db_page).text
base_page_soup = BeautifulSoup(base_page_html)

# %%
section_that_holds_data = list(base_page_soup.find_all('div', {'class': 'sqs-block-content'}))[0]

import re
CITY_REGEX_PATTERN = re.compile(r'(.*) (Metropolitan Police Department|Police Bureau|Sheriff\'s Office|Division of Police|Bureau of Police|Police Department).*')


jurisdiction_to_soup_map = {}
for l in section_that_holds_data:
    if l.strong and '✔️' in l.strong.text:
        try:
            jurisdiction_name = CITY_REGEX_PATTERN.findall(l.strong.text)[0]
            jurisdiction_to_soup_map[jurisdiction_name[0]] = l
        except IndexError:
            print('failed', l.strong.text)
        
print(jurisdiction_to_soup_map)
# Out:
# {'Albuquerque': <p class="" style="white-space:pre-wrap;"><strong>Albuquerque Police Department ✔️📝</strong><br/><a href="/s/Albuquerque-police-contract.pdf">Police Union Contract</a> (see also: <a href="/s/New-Mexico-PBR.pdf" target="_blank">New Mexico Police Bill of Rights</a>)<br/><a href="https://www.dropbox.com/s/o80983zlasmwlu5/Albuquerque%20Police%20Contract%20Police%20Accountability%20Review%207.10.15.pdf?dl=0" target="_blank">Police Union Contract Police Accountability Fact Sheet</a><br/><a href="https://www.muckrock.com/foi/albuquerque-343/police-union-contract-albuquerque-police-department-18457/">FOIA Request Submitted Via MuckRock</a></p>, 'Anaheim': <p class="" style="white-space:pre-wrap;"><strong>Anaheim Police Department ✔️</strong><br/><a href="/s/Anaheim-police-contract.pdf" target="_blank">Police Union Contract</a> (see also: <a href="/s/CApoliceofficersbillofrights.pdf" target="_blank">California Police Bill of Rights</a>)<br/><a href="https://www.muckrock.com/fo
# ...

# %%
chicago_soup = jurisdiction_to_soup_map['Chicago']

"""

"""
from typing import Dict

def parse_one_jurisdiction(jd: BeautifulSoup) -> Dict[str, str]:
    link_map = dict()
    for asset_link in jd.find_all('a'):
        category = asset_link.text
        href = asset_link.get('href')
        if href and href.startswith('/s'):
            url = f'{base_url}{href}'
        elif href and 'muckrock' in href:
            continue
        else:
            url = href

        link_map[category] = url
    return link_map
    
print(parse_one_jurisdiction(chicago_soup))
# Out:
# {'Police Union Contract': 'https://www.checkthepolice.org/s/Chicagopolicecontract.pdf', 'Illinois Police Bill of Rights': 'https://www.checkthepolice.org/s/Illinois-PBR.pdf', 'Police Union Contract Accountability Fact Sheet': 'https://www.dropbox.com/s/2o3dtucoap7fw7h/Chicago%20Police%20Contract%20Police%20Accountability%20Review%207.10.15.pdf?dl=0'}

# %%
"""
Perform the transformation for all jurisdictions
"""
all_jurisdiction_links = dict()
for jurisdiction, soup_data in jurisdiction_to_soup_map.items():
    all_jurisdiction_links[jurisdiction] = parse_one_jurisdiction(soup_data)

import pprint
pprint.pprint(all_jurisdiction_links)
# Out:
# {'Albuquerque': {'New Mexico Police Bill of Rights': 'https://www.checkthepolice.org/s/New-Mexico-PBR.pdf',
#                  'Police Union Contract': 'https://www.checkthepolice.org/s/Albuquerque-police-contract.pdf',
#                  'Police Union Contract Police Accountability Fact Sheet': 'https://www.dropbox.com/s/o80983zlasmwlu5/Albuquerque%20Police%20Contract%20Police%20Accountability%20Review%207.10.15.pdf?dl=0'},
#  'Anaheim': {'California Police Bill of Rights': 'https://www.checkthepolice.org/s/CApoliceofficersbillofrights.pdf',
#              'Police Union Contract': 'https://www.checkthepolice.org/s/Anaheim-police-contract.pdf'},
#  'Anchorage': {'Police Union Contract': 'https://www.checkthepolice.org/s/Anchorage-police-contract.PDF'},
#  'Aurora': {'Police Union Contract': 'https://www.checkthepolice.org/s/Aurora-police-contract.pdf'},
#  'Austin': {'Police Union Contract': 'https://www.checkthepolice.org/s/AustinPoliceContract.pdf'},
# ...

# %%
first_jursidction = next(iter(all_jurisdiction_links))
first_jurisdiction_data = all_jurisdiction_links[first_jursidction]
first_category = next(iter(first_jurisdiction_data))
first_category_link = first_jurisdiction_data[first_category]

print(first_category_link)
# Out:
# https://www.checkthepolice.org/s/Albuquerque-police-contract.pdf

# %%
import PyPDF2
import io
import textract
import tempfile


def get_pdf_from_link(url):
    if url.endswith('dl=0'):
        url = url[:-1] + "1"

    response = requests.get(url)
    with open('/tmp/contract.pdf', 'wb') as f:
        f.write(response.content)
    
    text_as_bytes = textract.process(f.name, method='tesseract', language='eng')
    return text_as_bytes.decode()

"""
text = textract.process(tmp.name, encoding='utf-8', method='tesseract', language='eng')
print(text)


with open(tmp.name, 'r') as f:
    pdfReader = PyPDF2.PdfFileReader(tmp)
pages = pdfReader.pages
for i, page in enumerate(pages):
    text = page.extractText()
    if text:
        print(text)
    else:
        print('wtf')
"""
# Out:
# "\ntext = textract.process(tmp.name, encoding='utf-8', method='tesseract', language='eng')\nprint(text)\n\n\nwith open(tmp.name, 'r') as f:\n    pdfReader = PyPDF2.PdfFileReader(tmp)\npages = pdfReader.pages\nfor i, page in enumerate(pages):\n    text = page.extractText()\n    if text:\n        print(text)\n    else:\n        print('wtf')\n"

# %%
result_one = get_pdf_from_link(first_category_link)
print(len(result_one))
print(result_one[:100])
# Out:
# 106792
# 2014-
# ink
#
# City of Albuquerque
# and
# Albuquerque Police Officers
# Association
#
# COLLECTIVE BARGAINING AGREEMENT
# EFFECTIVE JULY 16, 2014 TO JULY 16, 2015
# OPO ONAaAk WN a
#
# =.) aw
# 2386
#
# wo wow ww Pp hm mM Nw DY
# AF SRESBSRBNSARSSRBIESSSEANRTESH
#
# GENERAL LABORIMANAGEMENT r PROVISION -
# PAY PROVISIONS .
# INSURANCE COVERAGE and BENEFITS
# RETIREMENT PLANS
# VACATION LEAVE....
# RECOGNIZED HOLIDAYS
# MILITARY LEAVE ............+
# WORK WEEK...
# WORK HOURS
# WORK ASSIGNMENTB...........
# SENIORITY .. Pace
# BIDDING and VACANCIES..
# UNIFORMS, BODY ARMOR ............:0e0
# OCCUPATIONAL HEALTH and SAFETY.
# PROMOTIONAL PROCEDURES and POLICIES
# PERSONNEL FILES and RECORDS .
# CONDITIONS of EMPLOYMENT....
# INVESTIGATION and DISCIPLINE...........
#
# GRIEVANCE and APPEAL PROCEDURES .
# EMPLOYEE REIMBURSEMENTS..
# LEGAL PROTECTION......
# EMPLOYEE ASSISTANCE PROGRAMS...
# TAKE HOME CAR PLAN..
# FIREARMS ...........cec0
# CITY PROVIDED EQUIPMENT and TOOLS
# ...

# %%
from collections import defaultdict
all_jurisdiction_text = defaultdict(dict)
failed_to_parse = []

for jurisdiction, links in all_jurisdiction_links.items():
    for category, url in links.items():
        print(f"Fetching/parsing jurisdiction {jurisdiction} and category {category}")
        try:
            text = get_pdf_from_link(url)
            all_jurisdiction_text[jurisdiction][category] = text
        except:
            failed_to_parse.append([category, url])
# Out:
# Fetching/parsing jurisdiction Albuquerque and category Police Union Contract
# Fetching/parsing jurisdiction Albuquerque and category New Mexico Police Bill of Rights
# Fetching/parsing jurisdiction Albuquerque and category Police Union Contract Police Accountability Fact Sheet
# Fetching/parsing jurisdiction Anaheim and category Police Union Contract
# Fetching/parsing jurisdiction Anaheim and category California Police Bill of Rights
# Fetching/parsing jurisdiction Anchorage and category Police Union Contract
# Fetching/parsing jurisdiction Aurora and category Police Union Contract
# Fetching/parsing jurisdiction Austin and category Police Union Contract
# Fetching/parsing jurisdiction Bakersfield and category Police Union Contract
# Fetching/parsing jurisdiction Bakersfield and category California Police Bill of Rights
# Fetching/parsing jurisdiction Baltimore and category supervisors
# Fetching/parsing jurisdiction Baltimore and category non supervisors
# ...

# %%
with open('parsed.json', 'w') as f:
    json.dump(all_jurisdiction_text, f)

# %%
len(all_jurisdiction_text)
# Out:
# 75

# %%
print(all_jurisdiction_text["Tulsa"]["Police Union Contract"])
# Out:
# COLLECTIVE BARGAINING AGREEMENT
# BETWEEN
# CITY OF TULSA, OKLAHOMA
# AND
#
# LODGE #93 FRATERNAL ORDER OF POLICE
#
# EFFECTIVE JULY 1, 2015 THROUGH JUNE 30, 2016
# TABLE OF CONTENTS
#
# COLLECTIVE BARGAINING AGREEMENT.
# ARTICLE 1 - RECOGNITION...
# ARTICLE 2 - MANAGEMENT RIGHTS AND RESPONSIBILITIES
# ARTICLE 3 - SAVINGS CLAUSE....
# ARTICLE 4 - NONDISCRIMINATION ..
# ARTICLE 5 - PROHIBITION OF STRIKES
# ARTICLE 6 - SENIORITY
# ARTICLE 7 - GRIEVANCES AND ARBITRATION
# ARTICLE 8 - DUES DEDUCTION
# ARTICLE 9 - LODGE BUSINESS..
# ARTICLE 10 - BULLETIN BOARDS
# ARTICLE 11 - POLICE DEPARTMENT RULES AND REGULATIONS
# ARTICLE 12 - VACATIONS
# ARTICLE 13 - BASIC WORK PERIOD AND OVERTIME.
# ARTICLE 14 - HOLIDAYS.
# ARTICLE 15 - SICK LEAVE
# ARTICLE 16 - INJURY LEAVE.....
# ARTICLE 17 - FUNERAL LEAVE...
# ARTICLE 18 - LEAVES OF ABSENCE.
# ARTICLE 19 - EDUCATIONAL AND LANGUAGE INCENTIVE PAY
# ARTICLE 20 —- CLOTHING, EQUIPMENT, AND TRAINING ....
# ARTICLE 21 - WAGES....
# ...

# %%
import pathlib

base_path = pathlib.Path('./contracts')
import os
print(os.getcwd())
print(base_path.)
if not base_path.exists:
    print('he')
    base_path.mkdir()

for jur, cats in all_jurisdiction_text.items():
    for cat in cats:
        transformed_cat = cat.lower().replace(' ', '_').replace("'", '').replace('.', '_') + '.txt'
        if not (base_path / jur.lower()).is_dir:
            (base_path / jur.lower).mkdir()
            
        with open(base_path / jur.lower() / transformed_cat, 'w') as f:
            f.write(cats[cat])
# Out:
# /home/davidshere/src/scratch
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-66-0f4fd2d6a41b> in <module>
#      14             (base_path / jur.lower).mkdir()
#      15
# ---> 16         with open(base_path / jur.lower() / transformed_cat, 'w') as f:
#      17             f.write(cats[cat])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'contracts/anaheim/police_union_contract.txt'
